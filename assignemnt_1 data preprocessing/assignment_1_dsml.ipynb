# %% [markdown]
# 1 Perform the following operations using R/Python on suitable data sets:
#
# a) read data from different formats (like csv, xls)
#
# b) indexing and selecting data, sort data,
#
# c) describe attributes of data, checking data types of each column,
#
# d) counting unique values of data, format of each column, converting variable data type
# (e.g. from long to short, vice versa),
#
# e) identifying missing values and fill in the missing values

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
temp = pd.read_csv('/content/Customers.csv')

# %%
temp.head()
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# 3         Lawyer                0            2
# 4  Entertainment                2            6

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              2000 non-null   int64
#  1   Gender                  2000 non-null   object
#  2   Age                     2000 non-null   int64
#  3   Annual Income ($)       2000 non-null   int64
#  4   Spending Score (1-100)  2000 non-null   int64
#  5   Profession              1965 non-null   object
#  6   Work Experience         2000 non-null   int64
#  7   Family Size             2000 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 125.1+ KB

# %%
temp.describe()
# Out:
#         CustomerID          Age  Annual Income ($)  Spending Score (1-100)  \
# count  2000.000000  2000.000000        2000.000000             2000.000000
# mean   1000.500000    48.960000      110731.821500               50.962500
# std     577.494589    28.429747       45739.536688               27.934661
# min       1.000000     0.000000           0.000000                0.000000
# 25%     500.750000    25.000000       74572.000000               28.000000
# 50%    1000.500000    48.000000      110045.000000               50.000000
# 75%    1500.250000    73.000000      149092.750000               75.000000
# max    2000.000000    99.000000      189974.000000              100.000000
#
#        Work Experience  Family Size
# count      2000.000000  2000.000000
# mean          4.102500     3.768500
# std           3.922204     1.970749
# min           0.000000     1.000000
# 25%           1.000000     2.000000
# 50%           3.000000     4.000000
# ...

# %%
temp.loc[:, ['CustomerID', 'Gender','Age']]
# Out:
#       CustomerID  Gender  Age
# 0              1    Male   19
# 1              2    Male   21
# 2              3  Female   20
# 3              4  Female   23
# 4              5  Female   31
# ...          ...     ...  ...
# 1995        1996  Female   71
# 1996        1997  Female   91
# 1997        1998    Male   87
# 1998        1999    Male   77
# 1999        2000    Male   90
#
# [2000 rows x 3 columns]

# %%
temp.iloc[2:4, 0:2]
# Out:
#    CustomerID  Gender
# 2           3  Female
# 3           4  Female

# %%
sorted_data = temp.sort_values(by='Annual Income ($)', ascending=True)
sorted_data
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 169          170    Male   32                  0                      63
# 246          247    Male   23                  0                      96
# 272          273  Female   96               1000                      76
# 113          114    Male   19               2000                      46
# 96            97  Female   47               2000                      47
# ...          ...     ...  ...                ...                     ...
# 638          639  Female   59             189672                       8
# 1576        1577  Female   16             189689                      37
# 1825        1826    Male    7             189709                      18
# 1257        1258    Male   60             189945                      20
# 569          570  Female   91             189974                      37
#
#          Profession  Work Experience  Family Size
# ...

# %%
data_types = temp.dtypes
data_types
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income ($)          int64
# Spending Score (1-100)     int64
# Profession                object
# Work Experience            int64
# Family Size                int64
# dtype: object

# %%
unique_values = temp.nunique()
unique_values
# Out:
# CustomerID                2000
# Gender                       2
# Age                        100
# Annual Income ($)         1786
# Spending Score (1-100)     101
# Profession                   9
# Work Experience             18
# Family Size                  9
# dtype: int64

# %%
temp['Annual Income ($)'] = temp['Annual Income ($)'].astype('float')
temp
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19            15000.0                      39
# 1              2    Male   21            35000.0                      81
# 2              3  Female   20            86000.0                       6
# 3              4  Female   23            59000.0                      77
# 4              5  Female   31            38000.0                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71           184387.0                      40
# 1996        1997  Female   91            73158.0                      32
# 1997        1998    Male   87            90961.0                      14
# 1998        1999    Male   77           182109.0                       4
# 1999        2000    Male   90           110610.0                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
data_type = temp.dtypes
data_type
# Out:
# CustomerID                  int64
# Gender                     object
# Age                         int64
# Annual Income ($)         float64
# Spending Score (1-100)      int64
# Profession                 object
# Work Experience             int64
# Family Size                 int64
# dtype: object

# %%
missing = temp.isnull().sum()
missing
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income ($)         0
# Spending Score (1-100)    0
# Profession                0
# Work Experience           0
# Family Size               0
# dtype: int64

# %%
temp.fillna(0, inplace=True)
temp.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income ($)         0
# Spending Score (1-100)    0
# Profession                0
# Work Experience           0
# Family Size               0
# dtype: int64

# %%
temp
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19            15000.0                      39
# 1              2    Male   21            35000.0                      81
# 2              3  Female   20            86000.0                       6
# 3              4  Female   23            59000.0                      77
# 4              5  Female   31            38000.0                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71           184387.0                      40
# 1996        1997  Female   91            73158.0                      32
# 1997        1998    Male   87            90961.0                      14
# 1998        1999    Male   77           182109.0                       4
# 1999        2000    Male   90           110610.0                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
from matplotlib import pyplot as plt
sorted_data['Annual Income ($)'].plot(kind='hist', bins=20, title='Annual Income ($)')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
temp.groupby('Gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
temp.plot(kind='scatter', x='Age', y='Annual Income ($)', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
